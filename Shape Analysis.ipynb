# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

PC = pd.read_excel("PC.xlsx")
pi = np.pi
PC['lam1']=PC['D']/PC['t']*PC['Fy']/208000.0
PC['P_PcS'] = PC['P'] / (((PC['D'] - PC['t']) * PC['t'] * PC['Fy']) + ((PC['D'] - 2.0 * PC['t']) ** 2.0 * PC['fc'] / 4.0)) / pi * 1000.0
PC_CIRC=PC
X1 = PC[['D', 't', 'L', 'Fy', 'fc', 'lam1', 'P', 'P_PcS']]
column_labels = ['$D$', '$t$', '$L$', '$f_y$', '$f^\\prime_c$', '$\\lambda$','$P$','$p_{si}$']#\\tilde{p}

# Calculate Pearson's correlation coefficient between features (X1)
correlation_matrix = X1.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6),)
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", vmin=-1, vmax=1, center=0)

sns.set_context("paper", rc={"font.size": 12, "axes.titlesize": 12, "axes.labelsize": 12})
plt.xticks(fontsize=16);plt.yticks(fontsize=16)
plt.xticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.yticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.savefig("correlation_circ.png")

# Show the colorbar as a side bar

# Display the plot
plt.show()

PC  = pd.read_excel("PR.xlsx")#['P', 'EC4', 'FE', 'ref', 'Author ', 'Year', 'L', 'H', 'B', 't', 'Fy', 'fc', 'D/B', 'L/B', 'D/t']
PC['lam1']=PC['B']/PC['t']*(PC['Fy']/208000.0)**0.5
PC['P_PcS']=PC['P']/((PC['H']*PC['B'])*PC['Fy']+(PC['H']-2.0*PC['t'])*(PC['B']-2.0*PC['t'])*(PC['fc']-PC['Fy']))*1000.0
PC_REC=PC
X1=PC[['H', 'B', 't', 'L', 'Fy', 'fc', 'lam1', 'P', 'P_PcS']]
column_labels = ['$H$', '$B$', '$t$', '$L$', '$f_y$', '$f^\\prime_c$', '$\\lambda$','$P$','$p_{si}$']#\\tilde{p}

# Calculate Pearson's correlation coefficient between features (X1)
correlation_matrix = X1.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", vmin=-1, vmax=1, center=0)

sns.set_context("paper", rc={"font.size": 12, "axes.titlesize": 12, "axes.labelsize": 12})
plt.xticks(fontsize=16);plt.yticks(fontsize=16)

plt.xticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.yticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.savefig("correlation_rect.png")

# Show the colorbar as a side bar

# Display the plot
plt.show()

PC = pd.read_excel("PDS.xlsx")
PC['lam1']=PC['Do']/PC['to']*PC['fyo']/208000.0
PC['P_PcS']=PC['P']/((PC['Do']-PC['to'])*PC['to']*PC['fyo']+(PC['Di']-PC['ti'])*PC['ti']*PC['fyi']+((PC['Do']-2.0*PC['to'])**2.0-(PC['Di']-2.0*PC['ti'])**2.0)*PC['fc']/4.0)/pi*1000.0
PC_DS=PC

X1=PC[['Do', 'to', 'Di', 'ti', 'L', 'fyo', 'fyi', 'fc', 'lam1', 'P', 'P_PcS']]
column_labels = ['$D$', '$t$', '$D_i$', '$t_i$', '$L$', '$f_y$', '$f_{yi}$','$f^\\prime_c$', '$\\lambda$','$P$','$p_{si}$']#\\tilde{p}

# Calculate Pearson's correlation coefficient between features (X1)
correlation_matrix = X1.corr()
correlation_matrix=np.round(correlation_matrix, decimals=2)

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", vmin=-1, vmax=1, center=0)

sns.set_context("paper", rc={"font.size": 12, "axes.titlesize": 12, "axes.labelsize": 12})
plt.xticks(fontsize=15);plt.yticks(fontsize=15)

plt.xticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.yticks(ticks=np.arange(len(column_labels)) + 0.5, labels=column_labels)
plt.savefig("correlation_DS.png")

# Show the colorbar as a side bar

# Display the plot
plt.show()

# %%
from scipy.stats import norm, skew
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pi = np.pi
PC=PC_CIRC

fig = plt.figure(dpi=600);plt.rcParams['font.sans-serif'] = 'Times New Roman';sns.distplot(PC['P_PcS'], fit=norm)
(mu, sigma) = norm.fit(PC['P_PcS'])
print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma),'KDE Fit'],loc='upper right')
plt.ylabel('Frequency');plt.xlabel("$P_{si}$")
plt.savefig("Distribution_circ.png")



PC=PC_REC
fig = plt.figure(dpi=600);plt.rcParams['font.sans-serif'] = 'Times New Roman';sns.distplot(PC['P_PcS'], fit=norm)
(mu, sigma) = norm.fit(PC['P_PcS'])
print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma),'KDE Fit'],loc='upper right')
plt.ylabel('Frequency');plt.xlabel("$P_{si}$")
plt.savefig("Distribution_rect.png")



PC=PC_DS
fig = plt.figure(dpi=600);plt.rcParams['font.sans-serif'] = 'Times New Roman';sns.distplot(PC['P_PcS'], fit=norm)
(mu, sigma) = norm.fit(PC['P_PcS'])
print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma),'KDE Fit'],loc='upper right')
plt.ylabel('Frequency');plt.xlabel("$P_{si}$")
plt.savefig("Distribution_DS.png")
# Out:
# C:\Users\desti\AppData\Local\Temp\ipykernel_28328\68077077.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   fig = plt.figure(dpi=600);plt.rcParams['font.sans-serif'] = 'Times New Roman';sns.distplot(PC['P_PcS'], fit=norm)
#  mu = 1.23 and sigma = 0.14
# C:\Users\desti\AppData\Local\Temp\ipykernel_28328\68077077.py:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %% [markdown]
# shapley

# %%
PC=PC_CIRC
X=PC[['D','t','L','Fy','fc','lam1']];y=PC['P_PcS']
import catboost as cb
#X_encoded = pd.get_dummies(X, columns=[ 'Circular', 'TypeCon', 'TypeL',  'TypeH','Config'], drop_first=True )
#X_encoded.head()
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import base, metrics, model_selection, preprocessing, tree, utils
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV
from IPython.display import Image
import shap
import xgboost as xgb
#import pandas_profiling
import itertools
from math import pi
xg_mine1=cb.CatBoostRegressor(iterations=1135,learning_rate=0.09342109519812346,depth=15,subsample=0.4715732143809523,colsample_bylevel=0.9427303576347658,min_data_in_leaf= 48)
#xg_mine = xgb.XGBRegressor(n_estimators =100,max_depth=10,colsample_bytree= 0.95,alpha=1,subsample=0.90,learning_rate=0.1,random_state=123)
xg_mine1.fit(X, y)#trained on all data
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# 0:	learn: 0.1334139	total: 488ms	remaining: 9m 13s
# 1:	learn: 0.1276033	total: 910ms	remaining: 8m 35s
# 2:	learn: 0.1218660	total: 1.33s	remaining: 8m 22s
# 3:	learn: 0.1167372	total: 1.72s	remaining: 8m 6s
# 4:	learn: 0.1117506	total: 2.13s	remaining: 8m 1s
# 5:	learn: 0.1074709	total: 2.48s	remaining: 7m 46s
# 6:	learn: 0.1032692	total: 2.86s	remaining: 7m 41s
# 7:	learn: 0.0993884	total: 3.25s	remaining: 7m 37s
# 8:	learn: 0.0955288	total: 3.65s	remaining: 7m 36s
# 9:	learn: 0.0918198	total: 3.74s	remaining: 7m 1s
# 10:	learn: 0.0887754	total: 4.1s	remaining: 6m 59s
# 11:	learn: 0.0858160	total: 4.45s	remaining: 6m 56s
# 12:	learn: 0.0830444	total: 4.81s	remaining: 6m 55s
# 13:	learn: 0.0803682	total: 5.2s	remaining: 6m 56s
# 14:	learn: 0.0779456	total: 5.57s	remaining: 6m 55s
# 15:	learn: 0.0757711	total: 5.93s	remaining: 6m 55s
# ...

# %%
PC=PC_CIRC
X=PC[['D','t','L','Fy','fc','lam1']];y=PC['P_PcS']
featureName=[r'$D$', r'$t$', r'$L$', r'$f_y$', r'$f^\prime_c$', r'$\lambda$']
#featureName=[r'$D$', r'$t$', r'$L$', r'$f_y$', r'$f^\prime_c$', r'$e_{t}$', r'$e_{b}$', r'$P$', r'$p_{si}$']

plt.style.use('fast')
plt.rcParams['figure.figsize'] = (15, 4)
plt.rcParams['font.size'] = 15
plt.rcParams["font.family"] = "Times New Roman" # ou serif

shap.initjs()
explainer = shap.TreeExplainer(xg_mine1)
shap_values = explainer.shap_values(X)

# summarize the effects of all the features
plt.style.use('fast')
plt.rcParams['figure.figsize'] = (20, 8)
plt.rcParams['font.size'] = 20
plt.rcParams["font.family"] = "Times New Roman" 
shap.summary_plot(shap_values, X, feature_names= featureName,show=False)
plt.savefig('summary_plot_circ_short.png', dpi=300)
# Create a SHAP summary plot
plt.figure(figsize=(20, 8))
shap.summary_plot(shap_values, X, plot_type='bar', feature_names=featureName, show=False)
plt.savefig('shap_summary_plot_circ.png', dpi=300)
# Create a decision plot
plt.figure(figsize=(10, 8))
shap.decision_plot(explainer.expected_value, shap_values, X,feature_names= featureName)
plt.savefig('decision_plot_circ.png', dpi=500)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
PC=PC_REC
X=PC[['H', 'B', 't', 'L', 'Fy', 'fc', 'lam1']];y=PC['P_PcS']
xg_mine2 = cb.CatBoostRegressor(iterations=275,learning_rate=0.001065550011587194,depth=15,subsample=0.4179421399179088,colsample_bylevel= 0.5968784163069626,min_data_in_leaf=35)
#xgb.XGBRegressor(n_estimators =100,max_depth=10,colsample_bytree= 0.95,alpha=1,subsample=0.90,learning_rate=0.1,random_state=123)
xg_mine2.fit(X, y)
# Out:
# 0:	learn: 0.0832091	total: 210ms	remaining: 57.7s
# 1:	learn: 0.0831712	total: 455ms	remaining: 1m 2s
# 2:	learn: 0.0831393	total: 719ms	remaining: 1m 5s
# 3:	learn: 0.0831059	total: 990ms	remaining: 1m 7s
# 4:	learn: 0.0830685	total: 1.06s	remaining: 57.4s
# 5:	learn: 0.0830359	total: 1.32s	remaining: 59.1s
# 6:	learn: 0.0830062	total: 1.48s	remaining: 56.8s
# 7:	learn: 0.0829697	total: 1.65s	remaining: 55.2s
# 8:	learn: 0.0829368	total: 1.97s	remaining: 58.2s
# 9:	learn: 0.0829032	total: 2.26s	remaining: 60s
# 10:	learn: 0.0828691	total: 2.58s	remaining: 1m 2s
# 11:	learn: 0.0828356	total: 2.88s	remaining: 1m 3s
# 12:	learn: 0.0828032	total: 3.17s	remaining: 1m 3s
# 13:	learn: 0.0827776	total: 3.17s	remaining: 59.1s
# 14:	learn: 0.0827423	total: 3.4s	remaining: 59s
# 15:	learn: 0.0827118	total: 3.73s	remaining: 1m
# 16:	learn: 0.0826777	total: 3.92s	remaining: 59.5s
# 17:	learn: 0.0826433	total: 4.14s	remaining: 59.1s
# 18:	learn: 0.0826059	total: 4.36s	remaining: 58.7s
# ...

# %%
PC=PC_REC
X=PC[['H', 'B', 't', 'L', 'Fy', 'fc', 'lam1']];y=PC['P_PcS']
featureName=[r'$H$', r'$B$', r'$t$', r'$L$', r'$f_y$', r'$f^\prime_c$', r'$\lambda$']

plt.style.use('fast')
plt.rcParams['figure.figsize'] = (15, 4)
plt.rcParams['font.size'] = 15
plt.rcParams["font.family"] = "Times New Roman" # ou serif

shap.initjs()
explainer = shap.TreeExplainer(xg_mine2)
shap_values = explainer.shap_values(X)

# summarize the effects of all the features
plt.style.use('fast')
plt.rcParams['figure.figsize'] = (20, 8)
plt.rcParams['font.size'] = 20
plt.rcParams["font.family"] = "Times New Roman" 
shap.summary_plot(shap_values, X, feature_names= featureName,show=False)
plt.savefig('summary_plot_rect_short.png', dpi=300,bbox_inches='tight')
# Create a SHAP summary plot
plt.figure(figsize=(20, 8))
shap.summary_plot(shap_values, X, plot_type='bar', feature_names=featureName, show=False)
plt.savefig('shap_summary_plot_rect.png', dpi=300,bbox_inches='tight')

# Create a decision plot
plt.figure(figsize=(10, 8))
shap.decision_plot(explainer.expected_value, shap_values, X,feature_names= featureName)
plt.savefig('decision_plot_rect.png', dpi=500,bbox_inches='tight')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
PC=PC_DS
X=PC[['Do', 'to', 'Di', 'ti', 'L', 'fyo', 'fyi', 'fc', 'lam1']];y=PC['P_PcS']
xg_mine=cb.CatBoostRegressor(iterations=1013,learning_rate=0.06099838225705755,depth=16,subsample=0.550189739951005,colsample_bylevel=0.33796204656273937,min_data_in_leaf=7)
#xg_mine = xgb.XGBRegressor(n_estimators =100,max_depth=10,colsample_bytree= 0.95,alpha=1,subsample=0.90,learning_rate=0.1,random_state=123)
xg_mine.fit(X, y)
# Out:
# 0:	learn: 0.1453976	total: 58.9ms	remaining: 59.7s
# 1:	learn: 0.1408569	total: 192ms	remaining: 1m 37s
# 2:	learn: 0.1365930	total: 442ms	remaining: 2m 28s
# 3:	learn: 0.1328212	total: 632ms	remaining: 2m 39s
# 4:	learn: 0.1289928	total: 688ms	remaining: 2m 18s
# 5:	learn: 0.1270377	total: 689ms	remaining: 1m 55s
# 6:	learn: 0.1270377	total: 689ms	remaining: 1m 38s
# 7:	learn: 0.1235964	total: 904ms	remaining: 1m 53s
# 8:	learn: 0.1201913	total: 1.21s	remaining: 2m 14s
# 9:	learn: 0.1168941	total: 1.3s	remaining: 2m 10s
# 10:	learn: 0.1134595	total: 1.31s	remaining: 1m 58s
# 11:	learn: 0.1104223	total: 1.32s	remaining: 1m 49s
# 12:	learn: 0.1075076	total: 1.61s	remaining: 2m 3s
# 13:	learn: 0.1046714	total: 1.61s	remaining: 1m 54s
# 14:	learn: 0.1019674	total: 1.84s	remaining: 2m 2s
# 15:	learn: 0.0991022	total: 1.87s	remaining: 1m 56s
# 16:	learn: 0.0965489	total: 1.99s	remaining: 1m 56s
# 17:	learn: 0.0940821	total: 1.99s	remaining: 1m 50s
# ...

# %%
PC=PC_DS
X=PC[['Do', 'to', 'Di', 'ti', 'L', 'fyo', 'fyi', 'fc', 'lam1']];y=PC['P_PcS']
featureName=[r'$D$', r'$t$',r'$D_{i}$', r'$t_{i}$', r'$L$', r'$f_{y}$', r'$f_{yi}$', r'$f^\prime_c$', r'$\lambda$']

plt.style.use('fast')
plt.rcParams['figure.figsize'] = (15, 4)
plt.rcParams['font.size'] = 15
plt.rcParams["font.family"] = "Times New Roman" # ou serif

shap.initjs()
explainer = shap.TreeExplainer(xg_mine)
shap_values = explainer.shap_values(X)

# summarize the effects of all the features
plt.style.use('fast')
plt.rcParams['figure.figsize'] = (20, 8)
plt.rcParams['font.size'] = 20
plt.rcParams["font.family"] = "Times New Roman" 
shap.summary_plot(shap_values, X, feature_names= featureName,show=False)
plt.savefig('summary_plot_ds_short.png', dpi=300,bbox_inches='tight')
# Create a SHAP summary plot
plt.figure(figsize=(20, 8))
shap.summary_plot(shap_values, X, plot_type='bar', feature_names=featureName, show=False)
plt.savefig('shap_summary_plot_ds.png', dpi=300,bbox_inches='tight')
# Create a decision plot
plt.figure(figsize=(10, 8))
shap.decision_plot(explainer.expected_value, shap_values, X,feature_names= featureName)
plt.savefig('decision_plot_ds.png', dpi=300,bbox_inches='tight')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Create a decision plot
plt.figure(figsize=(30, 24))
shap.decision_plot(explainer.expected_value, shap_values, X,feature_names= featureName)
#plt.savefig('decision_plot_ds.png',bbox_inches='tight')
